# %% [markdown]
# ## Keras plus TensorFlow
# ### Installation Instructions
# * TensorFlow (not GPU) https://www.tensorflow.org/install/install_windows
# * Keras https://keras.io/#installation
# ### Task: There are diabetics dataset example. Do the same with Iris dataset or your project data

# %% [markdown]
# ### Codebook of iris dataset
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. Class variable (0 or 1)
#    6. Class variable (0 or 1)
#
#    Class Distribution: (class value 01 is interpreted as "Iris Setosa ", 10 - Iris Versicolour,11 - Iris Virginica )
#
#    Class Value  .... Number of instances
#
#    01 ................... 50
#
#    10 ................... 50
#
#    11 ................... 50

# %%
# Create first network with Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset
dataset = numpy.loadtxt("iris.data", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:5]
Y = dataset[:,4:6]
# create model
model = Sequential()
model.add(Dense(6, input_dim=5, init='uniform', activation='relu'))
model.add(Dense(3, init='uniform', activation='relu'))
model.add(Dense(2, init='uniform', activation='sigmoid'))
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Fit the model
model.fit(X, Y, epochs=150, batch_size=10,  verbose=2)
# calculate predictions
predictions = model.predict(X)
# round predictions
rounded = [round(x[0]) for x in predictions]
rounded2 = [round(x[1]) for x in predictions]
for i in range(0,150):
    print(i+1, rounded[i],rounded2[i])
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(6, input_dim=5, activation="relu", kernel_initializer="uniform")`
#   from ipykernel import kernelapp as app
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(3, activation="relu", kernel_initializer="uniform")`
#   app.launch_new_instance()
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(2, activation="sigmoid", kernel_initializer="uniform")`
# Epoch 1/150
#  - 1s - loss: 0.6923 - acc: 0.6400
# Epoch 2/150
#  - 0s - loss: 0.6903 - acc: 0.6667
# Epoch 3/150
#  - 0s - loss: 0.6884 - acc: 0.6667
# Epoch 4/150
#  - 0s - loss: 0.6864 - acc: 0.6667
# Epoch 5/150
#  - 0s - loss: 0.6848 - acc: 0.6667
# Epoch 6/150
#  - 0s - loss: 0.6830 - acc: 0.6667
# Epoch 7/150
#  - 0s - loss: 0.6814 - acc: 0.6667
# Epoch 8/150
# ...
